# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from openslide import open_slide, __library_version__ as openslide_version
import os
from PIL import Image
from skimage.color import rgb2gray
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from utils import *
from keras.models import Model, load_model, Sequential
from keras.layers import Dense,Flatten, Dropout, Conv2D, BatchNormalization, Activation, MaxPooling2D, concatenate
from keras.applications.inception_v3 import InceptionV3
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from utils import *

# %% [markdown]
# # Test

# %%
slide_nums = ['078','081', '091', '094', '096']
slide_paths = []
tumor_mask_paths = []
slide_windows1 = []
slide_windows2 = []
window_labels = []
for slide_num in slide_nums:
  slide_paths.append('tumor_' + slide_num + '.tif')
  tumor_mask_paths.append('tumor_' + slide_num + '_mask.tif')
for i in range(len(slide_paths)):
    window_1, window_2, labels = get_windows(slide_paths[i], tumor_mask_paths[i], (2,3), 
                                             stride=150, window_len=299)
    slide_windows1.extend(window_1)
    slide_windows2.extend(window_2)
    window_labels.extend(labels)

# %%
len(slide_windows1)
# Out:
# 19132

# %%
len(slide_windows1)
# Out:
# 19132

# %%
labels = np.array(window_labels)

# %%
w_tumor, w_tumor2, wo_tumor, wo_tumor2 = shuffle_data(slide_windows1, slide_windows2, window_labels)

# %%
len(w_tumor2)
# Out:
# 3834

# %%
len(wo_tumor2)
# Out:
# 3834

# %%
# del slide_windows1
# del slide_windows2
# del window_labels

# %% [markdown]
# # Split dataset

# %%
label_pos = np.ones(len(w_tumor))
label_neg = np.zeros(len(wo_tumor))
assert len(label_pos)==len(label_pos)

# %%
images1 = np.concatenate((w_tumor,wo_tumor), axis=0)
images2 = np.concatenate((w_tumor2,wo_tumor2), axis=0)
labels = np.concatenate((label_pos, label_neg))

# %%
len(labels)
# Out:
# 7668

# %%
shuffle = np.arange(len(labels))
np.random.shuffle(shuffle)

ds_images1 = np.array([images1[i] for i in shuffle])
ds_images2 = np.array([images2[i] for i in shuffle])
ds_labels = np.array([labels[i] for i in shuffle])
# ds_labels2 = np.array([labels[i] for i in shuffle])

# %%
ds_images1.shape
# Out:
# (7668, 299, 299, 3)

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(ds_images1, ds_labels, test_size=0.2, shuffle=False)
X_train2, X_test2, y_train2, y_test2 = train_test_split(ds_images2, ds_labels, test_size=0.2, shuffle=False)

# %%
with open('train1.npy', 'wb') as f:
    np.save(f, X_train1)
    np.save(f, y_train1)

with open('test1.npy', 'wb') as f:
    np.save(f, X_test1)
    np.save(f, y_test1)

# %%
with open('train2.npy', 'wb') as f:
    np.save(f, X_train2)
    np.save(f, y_train2)

with open('test2.npy', 'wb') as f:
    np.save(f, X_test2)
    np.save(f, y_test2)

# %% [markdown]
# # Load

# %%
with open('train1.npy', 'rb') as f:
    X_train1 = np.load(f)
    y_train1 = np.load(f)

# %%
with open('train2.npy', 'rb') as f:
    X_train2 = np.load(f)
    y_train2 = np.load(f)

# %%
with open('test1.npy', 'rb') as f:
    X_test1 = np.load(f)
    y_test1 = np.load(f)

# %%
with open('test2.npy', 'rb') as f:
    X_test2 = np.load(f)
    y_test2 = np.load(f)

# %%
len(y_test1)
# Out:
# 1534

# %%
len(y_train1)
# Out:
# 6134

# %%
X_train1.shape
# Out:
# (6134, 299, 299, 3)

# %%
1534//16
# Out:
# 95

# %% [markdown]
# # Build Model

# %%
type(X_train1)
# Out:
# numpy.ndarray

# %%
from keras.models import Model, load_model, Sequential
from keras.layers import Dense,Flatten, Dropout, Conv2D, BatchNormalization, Activation, MaxPooling2D, concatenate
from keras.applications.inception_v3 import InceptionV3
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
X_train1 = preprocess(X_train1)
X_train2 = preprocess(X_train2)
X_test1 = preprocess(X_test1)
X_test2 = preprocess(X_test2)

# %%
t = X_train1[0:16]

# %%
t.shape
# Out:
# (16, 299, 299, 3)

# %%
arr = np.concatenate([X_train1, X_test1])

# %%
arr.shape
# Out:
# (7668, 299, 299, 3)

# %%
arr2 = np.concatenate([X_train2, X_test2])

# %%
label = np.concatenate([y_train1, y_test1])

# %%
label.shape
# Out:
# (7668,)

# %%
w_tumor, w_tumor2, wo_tumor, wo_tumor2 = cut_data(arr, arr2, label, size = 1250)

# %%
del arr, arr2, label

# %%
len(w_tumor)
# Out:
# 1250

# %%
label_pos = np.ones(len(w_tumor))
label_neg = np.zeros(len(wo_tumor))
assert len(label_pos)==len(label_pos)

images1 = np.concatenate((w_tumor,wo_tumor), axis=0)
images2 = np.concatenate((w_tumor2,wo_tumor2), axis=0)
labels = np.concatenate((label_pos, label_neg))

len(labels)


shuffle = np.arange(len(labels))
np.random.shuffle(shuffle)

ds_images1 = np.array([images1[i] for i in shuffle])
ds_images2 = np.array([images2[i] for i in shuffle])
ds_labels = np.array([labels[i] for i in shuffle])
# ds_labels2 = np.array([labels[i] for i in shuffle])

ds_images1.shape

from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(ds_images1, ds_labels, test_size=0.2, shuffle=False)
X_train2, X_test2, y_train2, y_test2 = train_test_split(ds_images2, ds_labels, test_size=0.2, shuffle=False)

# %% [markdown]
# # Save!!!!!!!!!

# %%
with open('train1_s.npy', 'wb') as f:
    np.save(f, X_train1)
    np.save(f, y_train1)

with open('test1_s.npy', 'wb') as f:
    np.save(f, X_test1)
    np.save(f, y_test1)

with open('train2_s.npy', 'wb') as f:
    np.save(f, X_train2)
    np.save(f, y_train2)

with open('test2_s.npy', 'wb') as f:
    np.save(f, X_test2)
    np.save(f, y_test2)

# %%
# def gen_train():
#     for i in range(0,len(X_train1), 16):
#         train_1 = X_train1[i:i+16]
#         train_2 = X_train2[i:i+16]
#         label = y_train1[i:i+16]
#         batch_x = [train_1, train_2]
#         batch_y = label
#         yield (batch_x, batch_y)

# %%
# sess = tf.InteractiveSession()
# def create_dataset():
#     data = tf.data.Dataset.from_generator(gen, (tf.float32, tf.float32, tf.int32))
#     data = data.batch(16)
#     data = data.prefetch(16)
#     data = data.make_one_shot_iterator()

# %%
# final_ds = tf.Tensor()
# for i in range(0, len(X_train1), 16):
#     train_ds_1 = tf.data.Dataset.from_tensor_slices(X_train1[i:i+16])
#     #image_ds_1 = train_ds_1.map(preprocess)

#     train_ds_2 = tf.data.Dataset.from_tensor_slices(X_train2[i:i+16])
#     #image_ds_2 = train_ds_2.map(preprocess)
    
#     label_ds = tf.data.Dataset.from_tensor_slices(tf.cast(y_train1[i:i+16], tf.int64))

#     image_ds = tf.data.Dataset.zip(((train_ds_1,train_ds_2), label_ds))
#     final_ds = tf.concate(final_ds, image_ds)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_22056/2863156993.py in <module>
# ----> 1 final_ds = tf.Tensor()
#       2 for i in range(0, len(X_train1), 16):
#       3     train_ds_1 = tf.data.Dataset.from_tensor_slices(X_train1[i:i+16])
#       4     #image_ds_1 = train_ds_1.map(preprocess)
#       5
#
# TypeError: __init__() missing 3 required positional arguments: 'op', 'value_index', and 'dtype'

# %% [markdown]
# # Load !!!!!

# %%
with open('train1_s.npy', 'rb') as f:
    X_train1 = np.load(f)
    y_train1 = np.load(f)

with open('train2_s.npy', 'rb') as f:
    X_train2 = np.load(f)
    y_train2 = np.load(f)

with open('test1_s.npy', 'rb') as f:
    X_test1 = np.load(f)
    y_test1 = np.load(f)

with open('test2_s.npy', 'rb') as f:
    X_test2 = np.load(f)
    y_test2 = np.load(f)

# %%
train_ds = create_tf_dataset(X_train1, X_train2, y_train2)

# %%
X_train1.shape
# Out:
# (2000, 299, 299, 3)

# %%
X_test1.shape
# Out:
# (500, 299, 299, 3)

# %%
test_ds = create_tf_dataset(X_test1, X_test2, y_test2)

# %%
model = create_model() 
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  input_2input_2_2 (InputLayer)  [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  conv2d_94conv2d_94_2 (Conv2D)  (None, 149, 149, 32  864         ['input_2input_2_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  batch_normalization_94batch_no  (None, 149, 149, 32  96         ['conv2d_94conv2d_94_2[0][0]']
#  rmalization_94_2 (BatchNormali  )
#  zation)
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_94activation_94_2 (  (None, 149, 149, 32  0          ['batch_normalization_94batch_nor
#  Activation)                    )                                malization_94_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  conv2d_95conv2d_95_2 (Conv2D)  (None, 147, 147, 32  9216        ['activation_94activation_94_2[0]
#                                 )                                [0]']
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_95batch_no  (None, 147, 147, 32  96         ['conv2d_95conv2d_95_2[0][0]']
#  rmalization_95_2 (BatchNormali  )
#  zation)
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_95activation_95_2 (  (None, 147, 147, 32  0          ['batch_normalization_95batch_nor
#  Activation)                    )                                malization_95_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  conv2d_96conv2d_96_2 (Conv2D)  (None, 147, 147, 64  18432       ['activation_95activation_95_2[0]
#                                 )                                [0]']
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_96batch_no  (None, 147, 147, 64  192        ['conv2d_96conv2d_96_2[0][0]']
#  rmalization_96_2 (BatchNormali  )
#  zation)
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_96activation_96_2 (  (None, 147, 147, 64  0          ['batch_normalization_96batch_nor
#  Activation)                    )                                malization_96_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  max_pooling2d_4max_pooling2d_4  (None, 73, 73, 64)  0           ['activation_96activation_96_2[0]
#  _2 (MaxPooling2D)                                               [0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  conv2d_97conv2d_97_2 (Conv2D)  (None, 73, 73, 80)   5120        ['max_pooling2d_4max_pooling2d_4_
#                                                                  2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_97batch_no  (None, 73, 73, 80)  240         ['conv2d_97conv2d_97_2[0][0]']
#  rmalization_97_2 (BatchNormali
#  zation)
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  activation_97activation_97_2 (  (None, 73, 73, 80)  0           ['batch_normalization_97batch_nor
#  Activation)                                                     malization_97_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  conv2d_98conv2d_98_2 (Conv2D)  (None, 71, 71, 192)  138240      ['activation_97activation_97_2[0]
#                                                                  [0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_98batch_no  (None, 71, 71, 192)  576        ['conv2d_98conv2d_98_2[0][0]']
#  rmalization_98_2 (BatchNormali
#  zation)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  activation_98activation_98_2 (  (None, 71, 71, 192)  0          ['batch_normalization_98batch_nor
#  Activation)                                                     malization_98_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  max_pooling2d_5max_pooling2d_5  (None, 35, 35, 192)  0          ['activation_98activation_98_2[0]
#  _2 (MaxPooling2D)                                               [0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_102conv2d_102_2 (Conv2D  (None, 35, 35, 64)  12288       ['max_pooling2d_5max_pooling2d_5_
#  )                                                               2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_102batch_n  (None, 35, 35, 64)  192         ['conv2d_102conv2d_102_2[0][0]']
#  ormalization_102_2 (BatchNorma
#  lization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  activation_102activation_102_2  (None, 35, 35, 64)  0           ['batch_normalization_102batch_no
#   (Activation)                                                   rmalization_102_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  conv2d_100conv2d_100_2 (Conv2D  (None, 35, 35, 48)  9216        ['max_pooling2d_5max_pooling2d_5_
#  )                                                               2[0][0]']
#
#  conv2d_103conv2d_103_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_102activation_102_2[
#  )                                                               0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_100batch_n  (None, 35, 35, 48)  144         ['conv2d_100conv2d_100_2[0][0]']
#  ormalization_100_2 (BatchNorma
#  lization)
#
#  batch_normalization_103batch_n  (None, 35, 35, 96)  288         ['conv2d_103conv2d_103_2[0][0]']
#  ormalization_103_2 (BatchNorma
#  lization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  activation_100activation_100_2  (None, 35, 35, 48)  0           ['batch_normalization_100batch_no
#   (Activation)                                                   rmalization_100_2[0][0]']
#
#  activation_103activation_103_2  (None, 35, 35, 96)  0           ['batch_normalization_103batch_no
#   (Activation)                                                   rmalization_103_2[0][0]']
#
#  average_pooling2d_9average_poo  (None, 35, 35, 192)  0          ['max_pooling2d_5max_pooling2d_5_
#  ling2d_9_2 (AveragePooling2D)                                   2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  conv2d_99conv2d_99_2 (Conv2D)  (None, 35, 35, 64)   12288       ['max_pooling2d_5max_pooling2d_5_
#                                                                  2[0][0]']
#
#  conv2d_101conv2d_101_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_100activation_100_2[
#  )                                                               0][0]']
#
#  conv2d_104conv2d_104_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_103activation_103_2[
#  )                                                               0][0]']
#
#  conv2d_105conv2d_105_2 (Conv2D  (None, 35, 35, 32)  6144        ['average_pooling2d_9average_pool
#  )                                                               ing2d_9_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_99batch_no  (None, 35, 35, 64)  192         ['conv2d_99conv2d_99_2[0][0]']
#  rmalization_99_2 (BatchNormali
#  zation)
#
#  batch_normalization_101batch_n  (None, 35, 35, 64)  192         ['conv2d_101conv2d_101_2[0][0]']
#  ormalization_101_2 (BatchNorma
#  lization)
#
#  batch_normalization_104batch_n  (None, 35, 35, 96)  288         ['conv2d_104conv2d_104_2[0][0]']
#  ormalization_104_2 (BatchNorma
#  lization)
#
#  batch_normalization_105batch_n  (None, 35, 35, 32)  96          ['conv2d_105conv2d_105_2[0][0]']
#  ormalization_105_2 (BatchNorma
#  lization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  activation_99activation_99_2 (  (None, 35, 35, 64)  0           ['batch_normalization_99batch_nor
#  Activation)                                                     malization_99_2[0][0]']
#
#  activation_101activation_101_2  (None, 35, 35, 64)  0           ['batch_normalization_101batch_no
#   (Activation)                                                   rmalization_101_2[0][0]']
#
#  activation_104activation_104_2  (None, 35, 35, 96)  0           ['batch_normalization_104batch_no
#   (Activation)                                                   rmalization_104_2[0][0]']
#
#  activation_105activation_105_2  (None, 35, 35, 32)  0           ['batch_normalization_105batch_no
#   (Activation)                                                   rmalization_105_2[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  mixed0mixed0_2 (Concatenate)   (None, 35, 35, 256)  0           ['activation_99activation_99_2[0]
#                                                                  [0]',
#                                                                   'activation_101activation_101_2[
#                                                                  0][0]',
#                                                                   'activation_104activation_104_2[
#                                                                  0][0]',
#                                                                   'activation_105activation_105_2[
#                                                                  0][0]']
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_109conv2d_109_2 (Conv2D  (None, 35, 35, 64)  16384       ['mixed0mixed0_2[0][0]']
#  )
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_109batch_n  (None, 35, 35, 64)  192         ['conv2d_109conv2d_109_2[0][0]']
#  ormalization_109_2 (BatchNorma
#  lization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  activation_109activation_109_2  (None, 35, 35, 64)  0           ['batch_normalization_109batch_no
#   (Activation)                                                   rmalization_109_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  conv2d_107conv2d_107_2 (Conv2D  (None, 35, 35, 48)  12288       ['mixed0mixed0_2[0][0]']
#  )
#
#  conv2d_110conv2d_110_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_109activation_109_2[
#  )                                                               0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_107batch_n  (None, 35, 35, 48)  144         ['conv2d_107conv2d_107_2[0][0]']
#  ormalization_107_2 (BatchNorma
#  lization)
#
#  batch_normalization_110batch_n  (None, 35, 35, 96)  288         ['conv2d_110conv2d_110_2[0][0]']
#  ormalization_110_2 (BatchNorma
#  lization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  activation_107activation_107_2  (None, 35, 35, 48)  0           ['batch_normalization_107batch_no
#   (Activation)                                                   rmalization_107_2[0][0]']
#
#  activation_110activation_110_2  (None, 35, 35, 96)  0           ['batch_normalization_110batch_no
#   (Activation)                                                   rmalization_110_2[0][0]']
#
#  average_pooling2d_10average_po  (None, 35, 35, 256)  0          ['mixed0mixed0_2[0][0]']
#  oling2d_10_2 (AveragePooling2D
#  )
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  conv2d_106conv2d_106_2 (Conv2D  (None, 35, 35, 64)  16384       ['mixed0mixed0_2[0][0]']
#  )
#
#  conv2d_108conv2d_108_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_107activation_107_2[
#  )                                                               0][0]']
#
#  conv2d_111conv2d_111_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_110activation_110_2[
#  )                                                               0][0]']
#
#  conv2d_112conv2d_112_2 (Conv2D  (None, 35, 35, 64)  16384       ['average_pooling2d_10average_poo
#  )                                                               ling2d_10_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_106batch_n  (None, 35, 35, 64)  192         ['conv2d_106conv2d_106_2[0][0]']
#  ormalization_106_2 (BatchNorma
#  lization)
#
#  batch_normalization_108batch_n  (None, 35, 35, 64)  192         ['conv2d_108conv2d_108_2[0][0]']
#  ormalization_108_2 (BatchNorma
#  lization)
#
#  batch_normalization_111batch_n  (None, 35, 35, 96)  288         ['conv2d_111conv2d_111_2[0][0]']
#  ormalization_111_2 (BatchNorma
#  lization)
#
#  batch_normalization_112batch_n  (None, 35, 35, 64)  192         ['conv2d_112conv2d_112_2[0][0]']
#  ormalization_112_2 (BatchNorma
#  lization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_106activation_106_2  (None, 35, 35, 64)  0           ['batch_normalization_106batch_no
#   (Activation)                                                   rmalization_106_2[0][0]']
#
#  activation_108activation_108_2  (None, 35, 35, 64)  0           ['batch_normalization_108batch_no
#   (Activation)                                                   rmalization_108_2[0][0]']
#
#  activation_111activation_111_2  (None, 35, 35, 96)  0           ['batch_normalization_111batch_no
#   (Activation)                                                   rmalization_111_2[0][0]']
#
#  activation_112activation_112_2  (None, 35, 35, 64)  0           ['batch_normalization_112batch_no
#   (Activation)                                                   rmalization_112_2[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  mixed1mixed1_2 (Concatenate)   (None, 35, 35, 288)  0           ['activation_106activation_106_2[
#                                                                  0][0]',
#                                                                   'activation_108activation_108_2[
#                                                                  0][0]',
#                                                                   'activation_111activation_111_2[
#                                                                  0][0]',
#                                                                   'activation_112activation_112_2[
#                                                                  0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_116conv2d_116_2 (Conv2D  (None, 35, 35, 64)  18432       ['mixed1mixed1_2[0][0]']
#  )
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_116batch_n  (None, 35, 35, 64)  192         ['conv2d_116conv2d_116_2[0][0]']
#  ormalization_116_2 (BatchNorma
#  lization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  activation_116activation_116_2  (None, 35, 35, 64)  0           ['batch_normalization_116batch_no
#   (Activation)                                                   rmalization_116_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  conv2d_114conv2d_114_2 (Conv2D  (None, 35, 35, 48)  13824       ['mixed1mixed1_2[0][0]']
#  )
#
#  conv2d_117conv2d_117_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_116activation_116_2[
#  )                                                               0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_114batch_n  (None, 35, 35, 48)  144         ['conv2d_114conv2d_114_2[0][0]']
#  ormalization_114_2 (BatchNorma
#  lization)
#
#  batch_normalization_117batch_n  (None, 35, 35, 96)  288         ['conv2d_117conv2d_117_2[0][0]']
#  ormalization_117_2 (BatchNorma
#  lization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  activation_114activation_114_2  (None, 35, 35, 48)  0           ['batch_normalization_114batch_no
#   (Activation)                                                   rmalization_114_2[0][0]']
#
#  activation_117activation_117_2  (None, 35, 35, 96)  0           ['batch_normalization_117batch_no
#   (Activation)                                                   rmalization_117_2[0][0]']
#
#  average_pooling2d_11average_po  (None, 35, 35, 288)  0          ['mixed1mixed1_2[0][0]']
#  oling2d_11_2 (AveragePooling2D
#  )
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  conv2d_113conv2d_113_2 (Conv2D  (None, 35, 35, 64)  18432       ['mixed1mixed1_2[0][0]']
#  )
#
#  conv2d_115conv2d_115_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_114activation_114_2[
#  )                                                               0][0]']
#
#  conv2d_118conv2d_118_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_117activation_117_2[
#  )                                                               0][0]']
#
#  conv2d_119conv2d_119_2 (Conv2D  (None, 35, 35, 64)  18432       ['average_pooling2d_11average_poo
#  )                                                               ling2d_11_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_113batch_n  (None, 35, 35, 64)  192         ['conv2d_113conv2d_113_2[0][0]']
#  ormalization_113_2 (BatchNorma
#  lization)
#
#  batch_normalization_115batch_n  (None, 35, 35, 64)  192         ['conv2d_115conv2d_115_2[0][0]']
#  ormalization_115_2 (BatchNorma
#  lization)
#
#  batch_normalization_118batch_n  (None, 35, 35, 96)  288         ['conv2d_118conv2d_118_2[0][0]']
#  ormalization_118_2 (BatchNorma
# ...
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  activation_180activation_180_2  (None, 8, 8, 384)   0           ['batch_normalization_180batch_no
#   (Activation)                                                   rmalization_180_2[0][0]']
#
#  activation_184activation_184_2  (None, 8, 8, 384)   0           ['batch_normalization_184batch_no
#   (Activation)                                                   rmalization_184_2[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_181conv2d_181_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_180activation_180_2[
#  )                                                               0][0]']
#
#  conv2d_182conv2d_182_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_180activation_180_2[
#  )                                                               0][0]']
#
#  conv2d_185conv2d_185_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_184activation_184_2[
#  )                                                               0][0]']
#
#  conv2d_186conv2d_186_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_184activation_184_2[
#  )                                                               0][0]']
#
#  average_pooling2d_17average_po  (None, 8, 8, 2048)  0           ['mixed9mixed9_2[0][0]']
#  oling2d_17_2 (AveragePooling2D
#  )
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  conv2d_179conv2d_179_2 (Conv2D  (None, 8, 8, 320)   655360      ['mixed9mixed9_2[0][0]']
#  )
#
#  batch_normalization_181batch_n  (None, 8, 8, 384)   1152        ['conv2d_181conv2d_181_2[0][0]']
#  ormalization_181_2 (BatchNorma
#  lization)
#
#  batch_normalization_182batch_n  (None, 8, 8, 384)   1152        ['conv2d_182conv2d_182_2[0][0]']
#  ormalization_182_2 (BatchNorma
#  lization)
#
#  batch_normalization_185batch_n  (None, 8, 8, 384)   1152        ['conv2d_185conv2d_185_2[0][0]']
#  ormalization_185_2 (BatchNorma
#  lization)
#
#  batch_normalization_186batch_n  (None, 8, 8, 384)   1152        ['conv2d_186conv2d_186_2[0][0]']
#  ormalization_186_2 (BatchNorma
#  lization)
#
#  conv2d_187conv2d_187_2 (Conv2D  (None, 8, 8, 192)   393216      ['average_pooling2d_17average_poo
#  )                                                               ling2d_17_2[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_179batch_n  (None, 8, 8, 320)   960         ['conv2d_179conv2d_179_2[0][0]']
#  ormalization_179_2 (BatchNorma
#  lization)
#
#  activation_181activation_181_2  (None, 8, 8, 384)   0           ['batch_normalization_181batch_no
#   (Activation)                                                   rmalization_181_2[0][0]']
#
#  activation_182activation_182_2  (None, 8, 8, 384)   0           ['batch_normalization_182batch_no
#   (Activation)                                                   rmalization_182_2[0][0]']
#
#  activation_185activation_185_2  (None, 8, 8, 384)   0           ['batch_normalization_185batch_no
#   (Activation)                                                   rmalization_185_2[0][0]']
#
#  activation_186activation_186_2  (None, 8, 8, 384)   0           ['batch_normalization_186batch_no
#   (Activation)                                                   rmalization_186_2[0][0]']
#
#  batch_normalization_187batch_n  (None, 8, 8, 192)   576         ['conv2d_187conv2d_187_2[0][0]']
#  ormalization_187_2 (BatchNorma
#  lization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  activation_179activation_179_2  (None, 8, 8, 320)   0           ['batch_normalization_179batch_no
#   (Activation)                                                   rmalization_179_2[0][0]']
#
#  mixed9_1mixed9_1_2 (Concatenat  (None, 8, 8, 768)   0           ['activation_181activation_181_2[
#  e)                                                              0][0]',
#                                                                   'activation_182activation_182_2[
#                                                                  0][0]']
#
#  concatenate_3concatenate_3_2 (  (None, 8, 8, 768)   0           ['activation_185activation_185_2[
#  Concatenate)                                                    0][0]',
#                                                                   'activation_186activation_186_2[
#                                                                  0][0]']
#
#  activation_187activation_187_2  (None, 8, 8, 192)   0           ['batch_normalization_187batch_no
#   (Activation)                                                   rmalization_187_2[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  mixed10mixed10_2 (Concatenate)  (None, 8, 8, 2048)  0           ['activation_179activation_179_2[
#                                                                  0][0]',
#                                                                   'mixed9_1mixed9_1_2[0][0]',
#                                                                   'concatenate_3concatenate_3_2[0]
#                                                                  [0]',
#                                                                   'activation_187activation_187_2[
#                                                                  0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 4096)   0           ['mixed10[0][0]',
#                                                                   'mixed10mixed10_2[0][0]']
#
#  flatten (Flatten)              (None, 262144)       0           ['concatenate_4[0][0]']
#
#  dropout (Dropout)              (None, 262144)       0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 128)          33554560    ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 77,160,257
# Trainable params: 77,091,393
# Non-trainable params: 68,864
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # nb !!!!!!!!!

# %%
from numba import cuda 
device = cuda.get_current_device()
device.reset()

# %%
# model = multi_level_inception()

# %%
# Training
BATCH_SIZE = 16
model.compile(optimizer=RMSprop(),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_acc',
#                                                   min_delta=0.001,
#                                                   patience=3,
#                                                   verbose=1)

history = model.fit(
    train_ds,
    steps_per_epoch=int(len(X_train1)/BATCH_SIZE)+1,
    epochs=5,
    validation_data=test_ds,
    validation_steps=int(len(X_test1)/BATCH_SIZE)+1,)
# Out:
# Epoch 1/5
# 2022-12-22 07:14:51.409955: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
# 126/126 [==============================] - 102s 558ms/step - loss: 2.9633 - accuracy: 0.7803 - val_loss: 268.0880 - val_accuracy: 0.4863
# Epoch 2/5
# 126/126 [==============================] - 69s 547ms/step - loss: 0.4576 - accuracy: 0.8477 - val_loss: 90.0413 - val_accuracy: 0.5820
# Epoch 3/5
# 126/126 [==============================] - 69s 547ms/step - loss: 0.2595 - accuracy: 0.9236 - val_loss: 33.8503 - val_accuracy: 0.6855
# Epoch 4/5
# 126/126 [==============================] - 69s 551ms/step - loss: 0.2710 - accuracy: 0.9489 - val_loss: 13.2345 - val_accuracy: 0.9395
# Epoch 5/5
# 126/126 [==============================] - 69s 551ms/step - loss: 0.1775 - accuracy: 0.9524 - val_loss: 0.1001 - val_accuracy: 0.9805

# %%
model_filename = os.path.join('./model', "inception_sgd")
model.save(model_filename)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 188). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/inception_sgd/assets
# INFO:tensorflow:Assets written to: ./model/inception_sgd/assets

# %%
model_filename = os.path.join('./model', "inception_sgd")
new_model = tf.keras.models.load_model(model_filename)
# Out:
# 2022-12-22 07:39:46.333760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:46.346035: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:46.347805: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:46.350755: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-22 07:39:46.353635: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:46.355493: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:46.357258: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:47.092646: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:47.094705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:47.096382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-22 07:39:47.098079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13584 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
new_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  input_2input_2_2 (InputLayer)  [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  conv2d_94conv2d_94_2 (Conv2D)  (None, 149, 149, 32  864         ['input_2input_2_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  batch_normalization_94batch_no  (None, 149, 149, 32  96         ['conv2d_94conv2d_94_2[0][0]']
#  rmalization_94_2 (BatchNormali  )
#  zation)
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  activation_94activation_94_2 (  (None, 149, 149, 32  0          ['batch_normalization_94batch_nor
#  Activation)                    )                                malization_94_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  conv2d_95conv2d_95_2 (Conv2D)  (None, 147, 147, 32  9216        ['activation_94activation_94_2[0]
#                                 )                                [0]']
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  batch_normalization_95batch_no  (None, 147, 147, 32  96         ['conv2d_95conv2d_95_2[0][0]']
#  rmalization_95_2 (BatchNormali  )
#  zation)
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_95activation_95_2 (  (None, 147, 147, 32  0          ['batch_normalization_95batch_nor
#  Activation)                    )                                malization_95_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  conv2d_96conv2d_96_2 (Conv2D)  (None, 147, 147, 64  18432       ['activation_95activation_95_2[0]
#                                 )                                [0]']
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  batch_normalization_96batch_no  (None, 147, 147, 64  192        ['conv2d_96conv2d_96_2[0][0]']
#  rmalization_96_2 (BatchNormali  )
#  zation)
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_96activation_96_2 (  (None, 147, 147, 64  0          ['batch_normalization_96batch_nor
#  Activation)                    )                                malization_96_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  max_pooling2d_4max_pooling2d_4  (None, 73, 73, 64)  0           ['activation_96activation_96_2[0]
#  _2 (MaxPooling2D)                                               [0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  conv2d_97conv2d_97_2 (Conv2D)  (None, 73, 73, 80)   5120        ['max_pooling2d_4max_pooling2d_4_
#                                                                  2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_97batch_no  (None, 73, 73, 80)  240         ['conv2d_97conv2d_97_2[0][0]']
#  rmalization_97_2 (BatchNormali
#  zation)
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  activation_97activation_97_2 (  (None, 73, 73, 80)  0           ['batch_normalization_97batch_nor
#  Activation)                                                     malization_97_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  conv2d_98conv2d_98_2 (Conv2D)  (None, 71, 71, 192)  138240      ['activation_97activation_97_2[0]
#                                                                  [0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_98batch_no  (None, 71, 71, 192)  576        ['conv2d_98conv2d_98_2[0][0]']
#  rmalization_98_2 (BatchNormali
#  zation)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  activation_98activation_98_2 (  (None, 71, 71, 192)  0          ['batch_normalization_98batch_nor
#  Activation)                                                     malization_98_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  max_pooling2d_5max_pooling2d_5  (None, 35, 35, 192)  0          ['activation_98activation_98_2[0]
#  _2 (MaxPooling2D)                                               [0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_102conv2d_102_2 (Conv2D  (None, 35, 35, 64)  12288       ['max_pooling2d_5max_pooling2d_5_
#  )                                                               2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_102batch_n  (None, 35, 35, 64)  192         ['conv2d_102conv2d_102_2[0][0]']
#  ormalization_102_2 (BatchNorma
#  lization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  activation_102activation_102_2  (None, 35, 35, 64)  0           ['batch_normalization_102batch_no
#   (Activation)                                                   rmalization_102_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  conv2d_100conv2d_100_2 (Conv2D  (None, 35, 35, 48)  9216        ['max_pooling2d_5max_pooling2d_5_
#  )                                                               2[0][0]']
#
#  conv2d_103conv2d_103_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_102activation_102_2[
#  )                                                               0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_100batch_n  (None, 35, 35, 48)  144         ['conv2d_100conv2d_100_2[0][0]']
#  ormalization_100_2 (BatchNorma
#  lization)
#
#  batch_normalization_103batch_n  (None, 35, 35, 96)  288         ['conv2d_103conv2d_103_2[0][0]']
#  ormalization_103_2 (BatchNorma
#  lization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  activation_100activation_100_2  (None, 35, 35, 48)  0           ['batch_normalization_100batch_no
#   (Activation)                                                   rmalization_100_2[0][0]']
#
#  activation_103activation_103_2  (None, 35, 35, 96)  0           ['batch_normalization_103batch_no
#   (Activation)                                                   rmalization_103_2[0][0]']
#
#  average_pooling2d_9average_poo  (None, 35, 35, 192)  0          ['max_pooling2d_5max_pooling2d_5_
#  ling2d_9_2 (AveragePooling2D)                                   2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  conv2d_99conv2d_99_2 (Conv2D)  (None, 35, 35, 64)   12288       ['max_pooling2d_5max_pooling2d_5_
#                                                                  2[0][0]']
#
#  conv2d_101conv2d_101_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_100activation_100_2[
#  )                                                               0][0]']
#
#  conv2d_104conv2d_104_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_103activation_103_2[
#  )                                                               0][0]']
#
#  conv2d_105conv2d_105_2 (Conv2D  (None, 35, 35, 32)  6144        ['average_pooling2d_9average_pool
#  )                                                               ing2d_9_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_99batch_no  (None, 35, 35, 64)  192         ['conv2d_99conv2d_99_2[0][0]']
#  rmalization_99_2 (BatchNormali
#  zation)
#
#  batch_normalization_101batch_n  (None, 35, 35, 64)  192         ['conv2d_101conv2d_101_2[0][0]']
#  ormalization_101_2 (BatchNorma
#  lization)
#
#  batch_normalization_104batch_n  (None, 35, 35, 96)  288         ['conv2d_104conv2d_104_2[0][0]']
#  ormalization_104_2 (BatchNorma
#  lization)
#
#  batch_normalization_105batch_n  (None, 35, 35, 32)  96          ['conv2d_105conv2d_105_2[0][0]']
#  ormalization_105_2 (BatchNorma
#  lization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  activation_99activation_99_2 (  (None, 35, 35, 64)  0           ['batch_normalization_99batch_nor
#  Activation)                                                     malization_99_2[0][0]']
#
#  activation_101activation_101_2  (None, 35, 35, 64)  0           ['batch_normalization_101batch_no
#   (Activation)                                                   rmalization_101_2[0][0]']
#
#  activation_104activation_104_2  (None, 35, 35, 96)  0           ['batch_normalization_104batch_no
#   (Activation)                                                   rmalization_104_2[0][0]']
#
#  activation_105activation_105_2  (None, 35, 35, 32)  0           ['batch_normalization_105batch_no
#   (Activation)                                                   rmalization_105_2[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  mixed0mixed0_2 (Concatenate)   (None, 35, 35, 256)  0           ['activation_99activation_99_2[0]
#                                                                  [0]',
#                                                                   'activation_101activation_101_2[
#                                                                  0][0]',
#                                                                   'activation_104activation_104_2[
#                                                                  0][0]',
#                                                                   'activation_105activation_105_2[
#                                                                  0][0]']
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_109conv2d_109_2 (Conv2D  (None, 35, 35, 64)  16384       ['mixed0mixed0_2[0][0]']
#  )
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_109batch_n  (None, 35, 35, 64)  192         ['conv2d_109conv2d_109_2[0][0]']
#  ormalization_109_2 (BatchNorma
#  lization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  activation_109activation_109_2  (None, 35, 35, 64)  0           ['batch_normalization_109batch_no
#   (Activation)                                                   rmalization_109_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  conv2d_107conv2d_107_2 (Conv2D  (None, 35, 35, 48)  12288       ['mixed0mixed0_2[0][0]']
#  )
#
#  conv2d_110conv2d_110_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_109activation_109_2[
#  )                                                               0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_107batch_n  (None, 35, 35, 48)  144         ['conv2d_107conv2d_107_2[0][0]']
#  ormalization_107_2 (BatchNorma
#  lization)
#
#  batch_normalization_110batch_n  (None, 35, 35, 96)  288         ['conv2d_110conv2d_110_2[0][0]']
#  ormalization_110_2 (BatchNorma
#  lization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  activation_107activation_107_2  (None, 35, 35, 48)  0           ['batch_normalization_107batch_no
#   (Activation)                                                   rmalization_107_2[0][0]']
#
#  activation_110activation_110_2  (None, 35, 35, 96)  0           ['batch_normalization_110batch_no
#   (Activation)                                                   rmalization_110_2[0][0]']
#
#  average_pooling2d_10average_po  (None, 35, 35, 256)  0          ['mixed0mixed0_2[0][0]']
#  oling2d_10_2 (AveragePooling2D
#  )
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  conv2d_106conv2d_106_2 (Conv2D  (None, 35, 35, 64)  16384       ['mixed0mixed0_2[0][0]']
#  )
#
#  conv2d_108conv2d_108_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_107activation_107_2[
#  )                                                               0][0]']
#
#  conv2d_111conv2d_111_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_110activation_110_2[
#  )                                                               0][0]']
#
#  conv2d_112conv2d_112_2 (Conv2D  (None, 35, 35, 64)  16384       ['average_pooling2d_10average_poo
#  )                                                               ling2d_10_2[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_106batch_n  (None, 35, 35, 64)  192         ['conv2d_106conv2d_106_2[0][0]']
#  ormalization_106_2 (BatchNorma
#  lization)
#
#  batch_normalization_108batch_n  (None, 35, 35, 64)  192         ['conv2d_108conv2d_108_2[0][0]']
#  ormalization_108_2 (BatchNorma
#  lization)
#
#  batch_normalization_111batch_n  (None, 35, 35, 96)  288         ['conv2d_111conv2d_111_2[0][0]']
#  ormalization_111_2 (BatchNorma
#  lization)
#
#  batch_normalization_112batch_n  (None, 35, 35, 64)  192         ['conv2d_112conv2d_112_2[0][0]']
#  ormalization_112_2 (BatchNorma
#  lization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  activation_106activation_106_2  (None, 35, 35, 64)  0           ['batch_normalization_106batch_no
#   (Activation)                                                   rmalization_106_2[0][0]']
#
#  activation_108activation_108_2  (None, 35, 35, 64)  0           ['batch_normalization_108batch_no
#   (Activation)                                                   rmalization_108_2[0][0]']
#
#  activation_111activation_111_2  (None, 35, 35, 96)  0           ['batch_normalization_111batch_no
#   (Activation)                                                   rmalization_111_2[0][0]']
#
#  activation_112activation_112_2  (None, 35, 35, 64)  0           ['batch_normalization_112batch_no
#   (Activation)                                                   rmalization_112_2[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  mixed1mixed1_2 (Concatenate)   (None, 35, 35, 288)  0           ['activation_106activation_106_2[
#                                                                  0][0]',
#                                                                   'activation_108activation_108_2[
#                                                                  0][0]',
#                                                                   'activation_111activation_111_2[
#                                                                  0][0]',
#                                                                   'activation_112activation_112_2[
#                                                                  0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_116conv2d_116_2 (Conv2D  (None, 35, 35, 64)  18432       ['mixed1mixed1_2[0][0]']
#  )
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_116batch_n  (None, 35, 35, 64)  192         ['conv2d_116conv2d_116_2[0][0]']
#  ormalization_116_2 (BatchNorma
#  lization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  activation_116activation_116_2  (None, 35, 35, 64)  0           ['batch_normalization_116batch_no
#   (Activation)                                                   rmalization_116_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  conv2d_114conv2d_114_2 (Conv2D  (None, 35, 35, 48)  13824       ['mixed1mixed1_2[0][0]']
#  )
#
#  conv2d_117conv2d_117_2 (Conv2D  (None, 35, 35, 96)  55296       ['activation_116activation_116_2[
#  )                                                               0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_114batch_n  (None, 35, 35, 48)  144         ['conv2d_114conv2d_114_2[0][0]']
#  ormalization_114_2 (BatchNorma
#  lization)
#
#  batch_normalization_117batch_n  (None, 35, 35, 96)  288         ['conv2d_117conv2d_117_2[0][0]']
#  ormalization_117_2 (BatchNorma
#  lization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  activation_114activation_114_2  (None, 35, 35, 48)  0           ['batch_normalization_114batch_no
#   (Activation)                                                   rmalization_114_2[0][0]']
#
#  activation_117activation_117_2  (None, 35, 35, 96)  0           ['batch_normalization_117batch_no
#   (Activation)                                                   rmalization_117_2[0][0]']
#
#  average_pooling2d_11average_po  (None, 35, 35, 288)  0          ['mixed1mixed1_2[0][0]']
#  oling2d_11_2 (AveragePooling2D
#  )
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  conv2d_113conv2d_113_2 (Conv2D  (None, 35, 35, 64)  18432       ['mixed1mixed1_2[0][0]']
#  )
#
#  conv2d_115conv2d_115_2 (Conv2D  (None, 35, 35, 64)  76800       ['activation_114activation_114_2[
#  )                                                               0][0]']
#
#  conv2d_118conv2d_118_2 (Conv2D  (None, 35, 35, 96)  82944       ['activation_117activation_117_2[
#  )                                                               0][0]']
#
#  conv2d_119conv2d_119_2 (Conv2D  (None, 35, 35, 64)  18432       ['average_pooling2d_11average_poo
#  )                                                               ling2d_11_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_113batch_n  (None, 35, 35, 64)  192         ['conv2d_113conv2d_113_2[0][0]']
#  ormalization_113_2 (BatchNorma
#  lization)
#
#  batch_normalization_115batch_n  (None, 35, 35, 64)  192         ['conv2d_115conv2d_115_2[0][0]']
#  ormalization_115_2 (BatchNorma
#  lization)
#
#  batch_normalization_118batch_n  (None, 35, 35, 96)  288         ['conv2d_118conv2d_118_2[0][0]']
#  ormalization_118_2 (BatchNorma
# ...
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  activation_180activation_180_2  (None, 8, 8, 384)   0           ['batch_normalization_180batch_no
#   (Activation)                                                   rmalization_180_2[0][0]']
#
#  activation_184activation_184_2  (None, 8, 8, 384)   0           ['batch_normalization_184batch_no
#   (Activation)                                                   rmalization_184_2[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_181conv2d_181_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_180activation_180_2[
#  )                                                               0][0]']
#
#  conv2d_182conv2d_182_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_180activation_180_2[
#  )                                                               0][0]']
#
#  conv2d_185conv2d_185_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_184activation_184_2[
#  )                                                               0][0]']
#
#  conv2d_186conv2d_186_2 (Conv2D  (None, 8, 8, 384)   442368      ['activation_184activation_184_2[
#  )                                                               0][0]']
#
#  average_pooling2d_17average_po  (None, 8, 8, 2048)  0           ['mixed9mixed9_2[0][0]']
#  oling2d_17_2 (AveragePooling2D
#  )
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  conv2d_179conv2d_179_2 (Conv2D  (None, 8, 8, 320)   655360      ['mixed9mixed9_2[0][0]']
#  )
#
#  batch_normalization_181batch_n  (None, 8, 8, 384)   1152        ['conv2d_181conv2d_181_2[0][0]']
#  ormalization_181_2 (BatchNorma
#  lization)
#
#  batch_normalization_182batch_n  (None, 8, 8, 384)   1152        ['conv2d_182conv2d_182_2[0][0]']
#  ormalization_182_2 (BatchNorma
#  lization)
#
#  batch_normalization_185batch_n  (None, 8, 8, 384)   1152        ['conv2d_185conv2d_185_2[0][0]']
#  ormalization_185_2 (BatchNorma
#  lization)
#
#  batch_normalization_186batch_n  (None, 8, 8, 384)   1152        ['conv2d_186conv2d_186_2[0][0]']
#  ormalization_186_2 (BatchNorma
#  lization)
#
#  conv2d_187conv2d_187_2 (Conv2D  (None, 8, 8, 192)   393216      ['average_pooling2d_17average_poo
#  )                                                               ling2d_17_2[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_179batch_n  (None, 8, 8, 320)   960         ['conv2d_179conv2d_179_2[0][0]']
#  ormalization_179_2 (BatchNorma
#  lization)
#
#  activation_181activation_181_2  (None, 8, 8, 384)   0           ['batch_normalization_181batch_no
#   (Activation)                                                   rmalization_181_2[0][0]']
#
#  activation_182activation_182_2  (None, 8, 8, 384)   0           ['batch_normalization_182batch_no
#   (Activation)                                                   rmalization_182_2[0][0]']
#
#  activation_185activation_185_2  (None, 8, 8, 384)   0           ['batch_normalization_185batch_no
#   (Activation)                                                   rmalization_185_2[0][0]']
#
#  activation_186activation_186_2  (None, 8, 8, 384)   0           ['batch_normalization_186batch_no
#   (Activation)                                                   rmalization_186_2[0][0]']
#
#  batch_normalization_187batch_n  (None, 8, 8, 192)   576         ['conv2d_187conv2d_187_2[0][0]']
#  ormalization_187_2 (BatchNorma
#  lization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  activation_179activation_179_2  (None, 8, 8, 320)   0           ['batch_normalization_179batch_no
#   (Activation)                                                   rmalization_179_2[0][0]']
#
#  mixed9_1mixed9_1_2 (Concatenat  (None, 8, 8, 768)   0           ['activation_181activation_181_2[
#  e)                                                              0][0]',
#                                                                   'activation_182activation_182_2[
#                                                                  0][0]']
#
#  concatenate_3concatenate_3_2 (  (None, 8, 8, 768)   0           ['activation_185activation_185_2[
#  Concatenate)                                                    0][0]',
#                                                                   'activation_186activation_186_2[
#                                                                  0][0]']
#
#  activation_187activation_187_2  (None, 8, 8, 192)   0           ['batch_normalization_187batch_no
#   (Activation)                                                   rmalization_187_2[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  mixed10mixed10_2 (Concatenate)  (None, 8, 8, 2048)  0           ['activation_179activation_179_2[
#                                                                  0][0]',
#                                                                   'mixed9_1mixed9_1_2[0][0]',
#                                                                   'concatenate_3concatenate_3_2[0]
#                                                                  [0]',
#                                                                   'activation_187activation_187_2[
#                                                                  0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 4096)   0           ['mixed10[0][0]',
#                                                                   'mixed10mixed10_2[0][0]']
#
#  flatten (Flatten)              (None, 262144)       0           ['concatenate_4[0][0]']
#
#  dropout (Dropout)              (None, 262144)       0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 128)          33554560    ['dropout[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 77,160,257
# Trainable params: 77,091,393
# Non-trainable params: 68,864
# __________________________________________________________________________________________________

# %%
del X_train1, X_train2, X_test1, X_test2, y_train1, y_train2, y_test1, y_test2

# %%
# ## Compile and train model
# model.compile(optimizer=tf.train.AdamOptimizer(),
#               loss=tf.keras.losses.sparse_categorical_crossentropy, 
#               metrics = ['acc'])

# history = model.fit(ds_train, epochs=10, steps_per_epoch=steps_per_epoch_train, verbose=1)

# %% [markdown]
# # Make prediction

# %%
slide_path = "tumor_084.tif"
tumor_mask_path = "tumor_084_mask.tif"
levels = (2,3)
slide_windows1, slide_windows2, window_labels, coord_1, coord_2 =get_test_windows(slide_path,
                                                                                  tumor_mask_path, 
                                                                                  levels,
                                                                                  stride=150, 
                                                                                  window_len=299)

# %%
len(slide_windows1)
# Out:
# 2606

# %%
tumor_mask = open_slide(tumor_mask_path)
# Example: read the entire msliask at the same zoom level
mask_image = read_slide(tumor_mask, 
                        x=0, 
                        y=0, 
                        level=2, 
                        width=tumor_mask.level_dimensions[2][0], 
                        height=tumor_mask.level_dimensions[2][1])

# Note: the program provided by the dataset authors generates a mask with R,G,B channels.
# The mask info we need is in the first channel only.
# If you skip this step, the mask will be displayed as all black.
mask_image = mask_image[:,:,0]

plt.figure(figsize=(10,10), dpi=100)
plt.imshow(mask_image)

# %%
slide = open_slide(slide_path)
# Example: read the entire mask at the same zoom level
slide_image = read_slide(slide, 
                        x=0, 
                        y=0, 
                        level=2, 
                        width=slide.level_dimensions[2][0], 
                        height=slide.level_dimensions[2][1])

# Note: the program provided by the dataset authors generates a mask with R,G,B channels.
# The mask info we need is in the first channel only.
# If you skip this step, the mask will be displayed as all black.
# mask_image = mask_image[:,:,0]

plt.figure(figsize=(10,10), dpi=100)
plt.imshow(slide_image)

# %%
slide_windows1, slide_windows2 = preprocess(np.array(slide_windows1)), preprocess(np.array(slide_windows2))

# %%
slide_windows1.shape
# Out:
# (2606, 299, 299, 3)

# %%
test_ds = create_test_tfdataset(slide_windows1, slide_windows2)

# %%
pred = new_model.predict(test_ds, verbose = 1)
# Out:
# 2022-12-22 07:44:47.143246: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8200
# 652/652 [==============================] - 40s 48ms/step

# %%
pred.shape
# Out:
# (2606, 1)

# %%
heatmap = np.zeros_like(mask_image)

# %%
class_pred = generate_heat_map(new_model, pred, coord_1, heatmap, 0.1)

# %%
plt.figure(figsize=(10,10), dpi=100)
plt.imshow(heatmap)

# %%
class_pred = np.array(class_pred)

# %%
label = np.array(window_labels)

# %%
label.shape
# Out:
# (2606,)

# %%
np.sum(class_pred)
# Out:
# 4

# %%
np.sum(label)
# Out:
# 166

# %%
label
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
import numpy as np
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(label, class_pred)
metrics.auc(fpr, tpr)
# Out:
# 0.5120481927710844

# %%
acc = metrics.accuracy_score(label, class_pred)
print(acc)
# Out:
# 0.9378357636224098
